# %% [markdown]
# ## 1. WEBSCRAPING

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Web_scraping'
request = requests.get(url)

# %%
request
# Out:
# <Response [200]>

# %%
request.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Web scraping - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Web_scraping","wgTitle":"Web scraping","wgCurRevisionId":919618553,"wgRevisionId":919618553,"wgArticleId":2696619,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Danish-language sources (da)","Articles needing additional references from June 2017","All articles needing additional references","Articles needing additional references from October 2018","Articles with limited geographic scope from October 2015","USA-centric","Web scraping"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":[""
# ...

# %%
soup = BeautifulSoup(request.content,'html.parser')

# %%
lst = soup.select('ul')
len(lst)
# Out:
# 27

# %%
lst[7]
# Out:
# <ul><li><a href="/wiki/Greasemonkey" title="Greasemonkey">Greasemonkey</a></li>
# <li><a href="/wiki/Node.js" title="Node.js">Node.js</a></li>
# <li><a href="/wiki/PhantomJS" title="PhantomJS">PhantomJS</a> – scripted, <a href="/wiki/Headless_browser" title="Headless browser">headless browser</a> used for automating web page interaction.</li>
# <li><a href="/wiki/JQuery" title="JQuery">jQuery</a></li></ul>

# %%
type(lst[10])
# Out:
# bs4.element.Tag

# %%
ls_li = soup.select('a')
ls_li
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a>,
#  <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a>,
#  <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Web_scraping&amp;action=edit">improve this article</a>,
# ...

# %%
tag = ls_li[10]

# %%
ls_li[10]
# Out:
# <a class="external text" href="//www.google.com/search?tbs=bks:1&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">books</a>

# %%
tag.attrs
# Out:
# {'rel': ['nofollow'],
#  'class': ['external', 'text'],
#  'href': '//www.google.com/search?tbs=bks:1&q=%22Web+scraping%22+-wikipedia'}

# %%
tag.get('href')
# Out:
# '//www.google.com/search?tbs=bks:1&q=%22Web+scraping%22+-wikipedia'

# %%
#ls_lil = soup.select('href')
#ls_lil
# Out:
# []

# %%
tag.text
# Out:
# 'books'

# %%
len(ls_li)
# Out:
# 383

# %%
allpage = soup.find_all('a',['external','text'])
len(allpage)
# Out:
# 44

# %%
allpage
# Out:
# [<a class="external text" href="https://en.wikipedia.org/w/index.php?title=Web_scraping&amp;action=edit">improve this article</a>,
#  <a class="external text" href="//www.google.com/search?as_eq=wikipedia&amp;q=%22Web+scraping%22" rel="nofollow">"Web scraping"</a>,
#  <a class="external text" href="//www.google.com/search?tbm=nws&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">news</a>,
#  <a class="external text" href="//www.google.com/search?&amp;q=%22Web+scraping%22+site:news.google.com/newspapers&amp;source=newspapers" rel="nofollow">newspapers</a>,
#  <a class="external text" href="//www.google.com/search?tbs=bks:1&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">books</a>,
#  <a class="external text" href="//scholar.google.com/scholar?q=%22Web+scraping%22" rel="nofollow">scholar</a>,
#  <a class="external text" href="https://www.jstor.org/action/doBasicSearch?Query=%22Web+scraping%22&amp;acc=on&amp;wc=on" rel="nofollow">JSTOR</a>,
# ...

# %%
a = soup.find_all('a',attrs={'rel': ['nofollow'],'class': ['external', 'text']})
len(a)
# Out:
# 41

# %%
b = soup.find_all('a',attrs={'rel': ['nofollow']})
len(b)
# Out:
# 42

# %%
tag.children

# %%
import bs4

# %%
for li in tag.children:
    print(type(li))
    if isinstance(li,bs4.element.Tag):
        print('---childern----')
        for child in li.children:
            print(type(child))
        print('-------')
# Out:
# <class 'bs4.element.NavigableString'>

# %%
tag.parent
# Out:
# <span class="plainlinks"><i>Find sources:</i> <a class="external text" href="//www.google.com/search?as_eq=wikipedia&amp;q=%22Web+scraping%22" rel="nofollow">"Web scraping"</a> – <a class="external text" href="//www.google.com/search?tbm=nws&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">news</a> <b>·</b> <a class="external text" href="//www.google.com/search?&amp;q=%22Web+scraping%22+site:news.google.com/newspapers&amp;source=newspapers" rel="nofollow">newspapers</a> <b>·</b> <a class="external text" href="//www.google.com/search?tbs=bks:1&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">books</a> <b>·</b> <a class="external text" href="//scholar.google.com/scholar?q=%22Web+scraping%22" rel="nofollow">scholar</a> <b>·</b> <a class="external text" href="https://www.jstor.org/action/doBasicSearch?Query=%22Web+scraping%22&amp;acc=on&amp;wc=on" rel="nofollow">JSTOR</a></span>

# %%
tag.find_next_sibling
# Out:
# <bound method PageElement.find_next_sibling of <a class="external text" href="//www.google.com/search?tbs=bks:1&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">books</a>>

# %% [markdown]
# ## PARKRUN

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.parkrun.com/countries'

# %%
req = requests.get(url)
req
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
req.content
# Out:
# b'\n <?xml version="1.0" encoding="utf-8"?>\n <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN"\n  "http://www.w3.org/TR/xhtml1/DTD/xhtml1-strict.dtd">\n <html>\n   <head>\n     <title>403 Please don\'t scrape. See <a href=\'http://www.parkrun.com/scraping\'>http://www.parkrun.com/scraping</a> for details.</title>\n   </head>\n   <body>\n        <img src="https://images.parkrun.com/website/general/PR_Logo_Web_White.png">\n        <h1>Ooops!</h1>\nFull technical details below, but unfortunately our website is having difficulty serving your request.<p>This could be because we are applying an update, or because there\'s a problem with our systems, or how our systems handle your request.<p>Please bear with us, but if symptoms persist, please drop us an email at <a href="mailto:support@parkrun.com?subject=403 Error on parkrun website">support@parkrun.com</a>, including the following details and what you were doing that led to this error.<p>Regards<p>The parkrun technical team<br><a
# ...

# %%
url = 'https://www.parkrun.com/countries'
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
headers = {'User-Agent': user_agent}
response = requests.get(url,headers=headers)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'\n<!doctype html>\n\n<!--[if lt IE 7]><html lang="en-US" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if (IE 7)&!(IEMobile)]><html lang="en-US" class="no-js lt-ie9 lt-ie8"><![endif]-->\n<!--[if (IE 8)&!(IEMobile)]><html lang="en-US" class="no-js lt-ie9"><![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-US" class="no-js"><!--<![endif]-->\n\n\t<head>\n\t\t<meta charset="utf-8">\n\n\t\t<title>  Countries</title>\n\n\t\t<meta name="HandheldFriendly" content="True">\n\t\t<meta name="MobileOptimized" content="320">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0"/>\n\t\t<meta property="og:image" content="https://images.parkrun.com/website/general/parkrun_global.jpg" />\n\n\t\t\n\t\t<link rel="icon" href="https://www.parkrun.com/wp-content/themes/parkrun2014/favicon.png?v=4">\n\t\t<link rel="apple-touch-icon-precomposed" href="https://www.parkrun.com/wp-content/themes/parkrun2014/favicon-152.png?v=4">\n\t\t<meta name="msapplication-
# ...

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
lst_sections = soup.select('section')
len(lst_sections)
# Out:
# 23

# %%
lst_sections[5]
# Out:
# <section>
# <div class="section-wrap">
# <a class="img-link" href="http://www.parkrun.fr"><div class="img" style="background: transparent url(https://images.parkrun.com/website/group/flags/parkrun-flag-fra-fallback.png);background: rgba(255,255,255, 0) url(https://images.parkrun.com/website/group/flags/parkrun-flag-fra.svg);"></div></a>
# <h2 class="article-title">France</h2>
# <p>parkrun France launched in June 2015 under the watchful eye of Anita with the first event in Les Dougnes.<br/>
# <br/>
# </p>
# <a class="button green" href="http://www.parkrun.fr">Visit</a>
# </div>
# </section>

# %%
country_name = lst_sections[5].find_all('h2')[0].text
country_name
# Out:
# 'France'

# %%
lst_sections[5].select('a')[0].get('href')
# Out:
# 'http://www.parkrun.fr'

# %%
country_dict = {}
for country in range(0,len(lst_sections)):
    lst = lst_sections[country].find_all('h2')
    if len(lst) > 0:
        country_name = lst_sections[country].find_all('h2')[0].text
        country_url = lst_sections[country].select('a')[0].get('href')
        country_dict[country_name] = country_url

# %%
country_dict
# Out:
# {'Australia': 'http://www.parkrun.com.au/',
#  'Canada': 'http://www.parkrun.ca',
#  'Denmark': 'http://www.parkrun.dk/',
#  'Eswatini': 'https://www.parkrun.co.za/events/#8.06/-26.52/31.463',
#  'Finland': 'http://www.parkrun.fi/',
#  'France': 'http://www.parkrun.fr',
#  'Germany': 'http://www.parkrun.com.de',
#  'Ireland': 'http://www.parkrun.ie/',
#  'Italy': 'http://www.parkrun.it',
#  'Japan': 'https://www.parkrun.jp',
#  'Malaysia': 'http://www.parkrun.my/',
#  'Namibia': 'https://www.parkrun.co.za/events/#5.18/-23.071/16.756',
#  'Netherlands': 'https://blog.parkrun.com/nl/2019/09/12/parkrun-netherlands-coming-soon',
#  'New Zealand': 'http://www.parkrun.co.nz/',
#  'Norway': 'http://www.parkrun.no/',
#  'Poland': 'http://www.parkrun.pl/',
#  'Russia': 'http://www.parkrun.ru/',
#  'Singapore': 'http://www.parkrun.sg/',
#  'South Africa': 'http://www.parkrun.co.za/',
#  'Sweden': 'http://www.parkrun.se',
#  'United Kingdom': 'http://www.parkrun.org.uk/',
# ...

# %%
country_dict1 = {}
for country in range(0,len(lst_sections)):
    #lst = lst_sections[country].find_all('h2')
    try:
        country_name = lst_sections[country].find_all('h2')[0].text
        country_url = lst_sections[country].select('a')[0].get('href')
        country_dict[country_name] = country_url
    except:
        print('Data Not available')
# Out:
# Data Not available

# %%
country_dict1
# Out:
# {}

# %%
exclude = ['events','coming-soon']

# %%
for (name,url) in country_dict.items():
    if 'events'in url or 'coming-soon' in url:
        del country_dict[name]

# %%
for (name,url) in country_dict.items():
    for keyword in exclude:
        if keyword in url:
            del country_dict[name]

# %%
for (name,url) in country_dict.items():
    if any(keyword in url for keyword in exlude):
        del country_dict[name]

# %%
for (name,url) in list(country_dict.items()):
    if any(keyword in url for keyword in exclude):
        del country_dict[name]

# %%
country_dict
# Out:
# {'Australia': 'http://www.parkrun.com.au/',
#  'Canada': 'http://www.parkrun.ca',
#  'Denmark': 'http://www.parkrun.dk/',
#  'Finland': 'http://www.parkrun.fi/',
#  'France': 'http://www.parkrun.fr',
#  'Germany': 'http://www.parkrun.com.de',
#  'Ireland': 'http://www.parkrun.ie/',
#  'Italy': 'http://www.parkrun.it',
#  'Japan': 'https://www.parkrun.jp',
#  'Malaysia': 'http://www.parkrun.my/',
#  'New Zealand': 'http://www.parkrun.co.nz/',
#  'Norway': 'http://www.parkrun.no/',
#  'Poland': 'http://www.parkrun.pl/',
#  'Russia': 'http://www.parkrun.ru/',
#  'Singapore': 'http://www.parkrun.sg/',
#  'South Africa': 'http://www.parkrun.co.za/',
#  'Sweden': 'http://www.parkrun.se',
#  'United Kingdom': 'http://www.parkrun.org.uk/',
#  'USA': 'http://www.parkrun.us/'}

# %%
import json

# %%
url = 'https://images.parkrun.com/events.json'
events = requests.get(url)

# %%
content = events.content

# %%
eventi = json.loads(content)
eventi
# Out:
# {'countries': {'3': {'url': 'www.parkrun.com.au',
#    'bounds': [114.613067, -43.163256, 153.576356, -12.376205]},
#   '14': {'url': 'www.parkrun.ca',
#    'bounds': [-123.650306, 42.990553, -63.661271, 56.730253]},
#   '23': {'url': 'www.parkrun.dk',
#    'bounds': [8.442703, 55.474609, 12.635341, 56.987144]},
#   '30': {'url': 'www.parkrun.fi',
#    'bounds': [23.759243, 60.180235, 25.538652, 61.492554]},
#   '31': {'url': 'www.parkrun.fr',
#    'bounds': [-0.42901, 43.564162, 6.146281, 49.44128]},
#   '32': {'url': 'www.parkrun.com.de',
#    'bounds': [6.634672, 48.122967, 13.726508, 53.573708]},
#   '42': {'url': 'www.parkrun.ie',
#    'bounds': [-10.082041, 51.551575, -6.099962, 55.140535]},
#   '44': {'url': 'www.parkrun.it',
#    'bounds': [9.211192, 37.621125, 18.166117, 45.694128]},
#   '46': {'url': 'www.parkrun.jp',
#    'bounds': [131.417682, 31.908209, 139.941344, 36.209432]},
#   '57': {'url': 'www.parkrun.my',
# ...

# %%
eventi['events']['features'][0]
# Out:
# {'id': 1,
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-0.335791, 51.410992]},
#  'properties': {'eventname': 'bushy',
#   'EventLongName': 'Bushy parkrun',
#   'EventShortName': 'Bushy Park',
#   'countrycode': 97,
#   'seriesid': 1,
#   'EventLocation': 'Bushy Park, Teddington'}}

# %%
eventi.keys()
# Out:
# dict_keys(['countries', 'events'])

# %%
country_frame = pd.DataFrame.from_dict(eventi['countries'],orient='index')
country_frame
# Out:
#                    url                                            bounds
# 3   www.parkrun.com.au  [114.613067, -43.163256, 153.576356, -12.376205]
# 14      www.parkrun.ca   [-123.650306, 42.990553, -63.661271, 56.730253]
# 23      www.parkrun.dk       [8.442703, 55.474609, 12.635341, 56.987144]
# 30      www.parkrun.fi      [23.759243, 60.180235, 25.538652, 61.492554]
# 31      www.parkrun.fr         [-0.42901, 43.564162, 6.146281, 49.44128]
# 32  www.parkrun.com.de       [6.634672, 48.122967, 13.726508, 53.573708]
# 42      www.parkrun.ie     [-10.082041, 51.551575, -6.099962, 55.140535]
# 44      www.parkrun.it       [9.211192, 37.621125, 18.166117, 45.694128]
# 46      www.parkrun.jp    [131.417682, 31.908209, 139.941344, 36.209432]
# 57      www.parkrun.my      [101.698056, 2.916852, 101.733362, 3.122979]
# 65   www.parkrun.co.nz  [168.356606, -46.404097, 178.018082, -35.734968]
# 67      www.parkrun.no        [5.322763, 58.354828, 10.77791, 63.430394]
# ...

# %%
eventi['events'].keys()
# Out:
# dict_keys(['type', 'features'])

# %%
#events.keys()
#events['events'].keys()
#events['events']['features']
#import pandas as pd
#pd.DataFrame(events['events']['features'])
#pd.DataFrame([l['properties'] for l in events['events']['features']])
#event_frame = pd.DataFrame([l['properties'] for l in events['events']['features']])

#pd.DataFrame.from_dict(events['countries'], orient='index')
#countries_frame.drop(columns='bounds', inplace=True)
#countries_frame.reset_index(inplace=True)
#countries_frame.set_index('url', inplace=True)
----------------------------------------
#countries_name = pd.DataFrame.from_dict(country_dict, orient='index')
#countries_name.reset_index(inplace=True)
#countries_name.set_index(0, inplace=True)
#Ioannis 12:11 PM
----------------------------------------
from urllib import parse
parse.urlsplit(country_dict['Australia'])
for country, url in country_dict.items():
   clean_url = parse.urlsplit(url)
   country_dict[country] = clean_url.netloc
countries_name = pd.DataFrame.from_dict(country_dict, orient='index')
countries_name.reset_index(inplace=True)
countries_name.set_index(0, inplace=True)
--------------------------------------------
countries_frame['countryName'] = countries_name
countries_frame.reset_index(inplace=True)
countries_frame.set_index('index', inplace=True)
--------------------------------
event_frame[event_frame['countrycode'] == 3]

# %%
import pandas as pd

# %%
event_frame = pd.DataFrame([l['properties'] for l in eventi['events']['features']])
event_frame.head()
# Out:
#        eventname             EventLongName    EventShortName  countrycode  \
# 0          bushy             Bushy parkrun        Bushy Park           97
# 1      wimbledon  Wimbledon Common parkrun  Wimbledon Common           97
# 2       banstead    Banstead Woods parkrun    Banstead Woods           97
# 3       richmond          Richmond parkrun     Richmond Park           97
# 4  woodhousemoor    Woodhouse Moor parkrun    Woodhouse Moor           97
#
#    seriesid                        EventLocation
# 0         1               Bushy Park, Teddington
# 1         1                     Wimbledon Common
# 2         1             Banstead Woods, Coulsdon
# 3         1  Richmond Park, Richmond upon Thames
# 4         1                Woodhouse Moor, Leeds

# %%
#pd.DataFrame.from_dict(eventi['countries'], orient='index')
country_frame.drop(columns='bounds', inplace=True)
country_frame.reset_index(inplace=True)
country_frame.set_index('url', inplace=True)

# %%
country_frame
# Out:
#                    index
# url
# www.parkrun.com.au     3
# www.parkrun.ca        14
# www.parkrun.dk        23
# www.parkrun.fi        30
# www.parkrun.fr        31
# www.parkrun.com.de    32
# www.parkrun.ie        42
# www.parkrun.it        44
# www.parkrun.jp        46
# www.parkrun.my        57
# www.parkrun.co.nz     65
# www.parkrun.no        67
# www.parkrun.pl        74
# www.parkrun.ru        79
# www.parkrun.sg        82
# www.parkrun.co.za     85
# www.parkrun.se        88
# www.parkrun.org.uk    97
# www.parkrun.us        98

# %%
country_dict
# Out:
# {'Australia': 'http://www.parkrun.com.au/',
#  'Canada': 'http://www.parkrun.ca',
#  'Denmark': 'http://www.parkrun.dk/',
#  'Finland': 'http://www.parkrun.fi/',
#  'France': 'http://www.parkrun.fr',
#  'Germany': 'http://www.parkrun.com.de',
#  'Ireland': 'http://www.parkrun.ie/',
#  'Italy': 'http://www.parkrun.it',
#  'Japan': 'https://www.parkrun.jp',
#  'Malaysia': 'http://www.parkrun.my/',
#  'New Zealand': 'http://www.parkrun.co.nz/',
#  'Norway': 'http://www.parkrun.no/',
#  'Poland': 'http://www.parkrun.pl/',
#  'Russia': 'http://www.parkrun.ru/',
#  'Singapore': 'http://www.parkrun.sg/',
#  'South Africa': 'http://www.parkrun.co.za/',
#  'Sweden': 'http://www.parkrun.se',
#  'United Kingdom': 'http://www.parkrun.org.uk/',
#  'USA': 'http://www.parkrun.us/'}

# %%
country_frame = pd.DataFrame.from_dict(country_dict, orient='index')
country_frame.reset_index(inplace=True)
country_frame.set_index(0, inplace=True)

# %%
country_frame
# Out:
#                                      index
# 0
# http://www.parkrun.com.au/       Australia
# http://www.parkrun.ca               Canada
# http://www.parkrun.dk/             Denmark
# http://www.parkrun.fi/             Finland
# http://www.parkrun.fr               France
# http://www.parkrun.com.de          Germany
# http://www.parkrun.ie/             Ireland
# http://www.parkrun.it                Italy
# https://www.parkrun.jp               Japan
# http://www.parkrun.my/            Malaysia
# http://www.parkrun.co.nz/      New Zealand
# http://www.parkrun.no/              Norway
# http://www.parkrun.pl/              Poland
# http://www.parkrun.ru/              Russia
# http://www.parkrun.sg/           Singapore
# http://www.parkrun.co.za/     South Africa
# http://www.parkrun.se               Sweden
# http://www.parkrun.org.uk/  United Kingdom
# http://www.parkrun.us/                 USA
